# %%
import backtrader as bt
import datetime
import pandas as pd

# %%
# Create a Stratey
class ToyStrategy(bt.Strategy):
    '''
    Empty strategy is used to study indicators
    '''
    params = (
        ('none', 0),
    )
    
    def log(self, txt):
        ''' Logging function for this strategy'''
        dt = self.datas[0].datetime.datetime(0)
        print('%s, %s' % (dt.isoformat(), txt))
        
    def __init__(self):
        #bt.talib.KAMA(self.data0.close, timeperiod=3)
        pass
        
    def notify_order(self, order):
        #print(order)
        pass
        
    def next(self):
        self.log('next:{}-{}'.format(self.data0.close[0], len(self)))
        l = len(self)
        
        if 1==l:
            self.log('buy1')
            self.buy(size=1)
        elif 2==l:
            self.log('sell2')
            self.sell(size=2)
        elif 3==l:
            self.log('close')
            self.close()
    
    def stop(self):
        pass

# %%
cerebro = bt.Cerebro(oldtrades=False, stdstats=False)

from simplelivingfeed import SimpleLivingData
from autoguibroker import AutoGuiBroker

feed = SimpleLivingData('ixic', timeframe=bt.TimeFrame.Seconds, compression=30)
cerebro.adddata(feed, name='simple living')
#cerebro.resampledata(feed, name='cy_weekly', timeframe=bt.TimeFrame.Minutes, compression=1)

cerebro.addstrategy(ToyStrategy)

#cerebro.broker = AutoGuiBroker()

# init cash
cerebro.broker.setcash(10000.0)

print('Starting Running')

result = cerebro.run()

print('Finish Running')
# Out:
# Starting Running
# 2020-06-24T00:11:00, next:10187.709-1
# 2020-06-24T00:11:00, buy1
# Ref: 1
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 1
# Price: None
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 0
# ExecType: Market
# CommInfo: None
# End of Session: 737600.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# Ref: 1
# OrdType: 0
# OrdType: Buy
# Status: 7
# Status: Margin
# Size: 1
# Price: None
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 0
# ExecType: Market
# CommInfo: None
# End of Session: 737600.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# 2020-06-24T00:11:30, next:10191.9336-2
# 2020-06-24T00:11:30, sell2
# Ref: 2
# OrdType: 1
# OrdType: Sell
# Status: 1
# Status: Submitted
# Size: -2
# Price: None
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 0
# ExecType: Market
# CommInfo: None
# End of Session: 737600.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# Ref: 2
# OrdType: 1
# OrdType: Sell
# Status: 2
# Status: Accepted
# Size: -2
# Price: None
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 0
# ExecType: Market
# CommInfo: None
# End of Session: 737600.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# Ref: 2
# OrdType: 1
# OrdType: Sell
# Status: 4
# Status: Completed
# Size: -2
# Price: None
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 0
# ExecType: Market
# CommInfo: <backtrader.comminfo.CommInfoBase object at 0x10ed7ed50>
# End of Session: 737600.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# 2020-06-24T00:12:00, next:10192.6617-3
# 2020-06-24T00:12:00, close
# Ref: 3
# OrdType: 0
# OrdType: Buy
# Status: 1
# Status: Submitted
# Size: 2
# Price: None
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 0
# ExecType: Market
# CommInfo: None
# End of Session: 737600.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# Ref: 3
# OrdType: 0
# OrdType: Buy
# Status: 2
# Status: Accepted
# Size: 2
# Price: None
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 0
# ExecType: Market
# CommInfo: None
# End of Session: 737600.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: True
# Ref: 3
# OrdType: 0
# OrdType: Buy
# Status: 4
# Status: Completed
# Size: 2
# Price: None
# Price Limit: None
# TrailAmount: None
# TrailPercent: None
# ExecType: 0
# ExecType: Market
# CommInfo: <backtrader.comminfo.CommInfoBase object at 0x10ed7ed50>
# End of Session: 737600.9999999999
# Info: AutoOrderedDict()
# Broker: None
# Alive: False
# 2020-06-24T00:12:30, next:10192.5286-4
# 2020-06-24T00:13:00, next:10192.511-5
# 2020-06-24T00:13:30, next:10190.1938-6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-d1f0f6c4d278> in <module>
#      17 print('Starting Running')
#      18
# ---> 19 result = cerebro.run()
#      20
#      21 print('Finish Running')
#
# ~/gitrepos/backtrader_bilibili_study/lib/python3.7/site-packages/backtrader/cerebro.py in run(self, **kwargs)
#    1125             # let's skip process "spawning"
#    1126             for iterstrat in iterstrats:
# -> 1127                 runstrat = self.runstrategies(iterstrat)
#    1128                 self.runstrats.append(runstrat)
#    1129                 if self._dooptimize:
#
# ~/gitrepos/backtrader_bilibili_study/lib/python3.7/site-packages/backtrader/cerebro.py in runstrategies(self, iterstrat, predata)
#    1296                     self._runnext_old(runstrats)
#    1297                 else:
# -> 1298                     self._runnext(runstrats)
#    1299
#    1300             for strat in runstrats:
#
# ~/gitrepos/backtrader_bilibili_study/lib/python3.7/site-packages/backtrader/cerebro.py in _runnext(self, runstrats)
#    1540                 qlapse = datetime.datetime.utcnow() - qstart
#    1541                 d.do_qcheck(newqcheck, qlapse.total_seconds())
# -> 1542                 drets.append(d.next(ticks=False))
#    1543
#    1544             d0ret = any((dret for dret in drets))
#
# ~/gitrepos/backtrader_bilibili_study/lib/python3.7/site-packages/backtrader/feed.py in next(self, datamaster, ticks)
#     405
#     406             # not preloaded - request next bar
# --> 407             ret = self.load()
#     408             if not ret:
#     409                 # if load cannot produce bars - forward the result
#
# ~/gitrepos/backtrader_bilibili_study/lib/python3.7/site-packages/backtrader/feed.py in load(self)
#     477
#     478             if not self._fromstack(stash=True):
# --> 479                 _loadret = self._load()
#     480                 if not _loadret:  # no bar use force to make sure in exactbars
#     481                     # the pointer is undone this covers especially (but not
#
# ~/gitrepos/backtrader_bilibili_study/small_toy/simplelivingfeed.py in _load(self)
#      33     def _load(self):
#      34         # request data
# ---> 35         msg = self._req_data()
#      36         if msg is None:
#      37             # No more data
#
# ~/gitrepos/backtrader_bilibili_study/small_toy/simplelivingfeed.py in _req_data(self)
#      56
#      57         # sleep some time
# ---> 58         time.sleep(self.p.sleeptime)
#      59
#      60         msg = dict()
#
# KeyboardInterrupt:
