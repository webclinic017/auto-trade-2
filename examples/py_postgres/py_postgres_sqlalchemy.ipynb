# %%
import sqlalchemy 

db_pg = {
    # "host": "192.168.31.110",
    # "host": "192.168.0.135",
    "host": "127.0.0.1",
    "port": 5433, # alpha-pg 
    "user": "postgres",
    "password": "postgres",
    "db": "k_house",
}
user = db_pg["user"]
password = db_pg["password"]
host = db_pg["host"]
port = db_pg["port"]
dbname = db_pg["db"]

url=f'postgresql://{user}:{password}@{host}:{port}/{dbname}'

# %%
import sqlalchemy
from sqlalchemy_utils import database_exists, create_database
engine = sqlalchemy.create_engine(
    url=f'postgresql://{user}:{password}@{host}:{port}/{dbname}',)
if not database_exists(engine.url):
    print(f'not exit db {engine.url}')
    create_database(engine.url)
print(f'exit db {database_exists(engine.url)}: {engine.url}')
# Out:
# exit db True: postgresql://postgres:postgres@127.0.0.1:5433/k_house

# %%
engine = sqlalchemy.create_engine(url= url)
insp = sqlalchemy.inspect(engine)

# %%
insp.get_table_names()
# Out:
# ['stock_sz_a_spot_em',
#  'stock_sector_spot_sina',
#  'stock_institute_hold_sina',
#  'stock_zh_a_daily_test',
#  'stock_zh_a_hist_daily_test',
#  'stock_zh_a_hist_163_daily_test',
#  'stock_zh_a_hist_minute_sina_test',
#  'stock_zh_a_hist_minute_em_test',
#  'stock_zh_a_hist_pre_minute_em_test',
#  'stock_zh_a_tick_tx_test',
#  'stock_zh_a_tick_tx_js_test',
#  'stock_zh_a_tick_163_test',
#  'stock_info_a_code_name_test',
#  'stock_zh_index_spot_test',
#  'stock_zh_a_spot_test',
#  'stock_zh_a_spot_em_test',
#  'stock_sh_a_spot_em',
#  'stock_a_history_1d_000001',
#  'stock_a_codes',
#  'stock_info_a_code_name']

# %%
import pandas as pd

# %%
table_name = 'stock_a_history_1d_000001'
query_days = 20 
sql_cmd = 'SELECT * FROM {} LIMIT {};'.format(table_name, query_days)
db_df = pd.read_sql(sql=sql_cmd, con=engine)
db_df
# Out:
#     id        date  open  close  high   low  volume    amount  amplitude  \
# 0    0  1991-04-03 -0.97  -0.97 -0.97 -0.97       1    5000.0        0.0
# 1    1  1991-04-04 -0.97  -0.97 -0.97 -0.97       3   15000.0        0.0
# 2    2  1991-04-05 -0.97  -0.97 -0.97 -0.97       2   10000.0        0.0
# 3    3  1991-04-06 -0.97  -0.97 -0.97 -0.97       7   34000.0        0.0
# 4    4  1991-04-08 -0.97  -0.97 -0.97 -0.97       2   10000.0        0.0
# 5    5  1991-04-09 -0.97  -0.97 -0.97 -0.97       4   19000.0        0.0
# 6    6  1991-04-10 -0.97  -0.97 -0.97 -0.97      15   71000.0        0.0
# 7    7  1991-04-12 -0.98  -0.98 -0.98 -0.98       8   38000.0        0.0
# 8    8  1991-04-13 -0.98  -0.98 -0.98 -0.98       5   23000.0        0.0
# 9    9  1991-04-16 -0.98  -0.98 -0.98 -0.98       2    9000.0        0.0
# 10  10  1991-04-17 -0.98  -0.98 -0.98 -0.98       1    4615.0        0.0
# 11  11  1991-04-18 -0.98  -0.98 -0.98 -0.98       4   18000.0        0.0
# ...

# %%
table_name = 'stock_a_history_1d_000001'
query_days = 20 
sql_cmd = 'SELECT * FROM {} ORDER BY date DESC LIMIT {};'.format(table_name, query_days)
db_df = pd.read_sql(sql=sql_cmd, con=engine)
db_df
# last_id = db_df['id'].iloc[-1]
# last_id
# Out:
#       id        date   open  close   high    low   volume        amount  \
# 0   7549  2022-11-16  11.97  11.82  12.05  11.79  1278693  1.519134e+09
# 1   7548  2022-11-15  11.86  12.01  12.18  11.83  1573901  1.891250e+09
# 2   7547  2022-11-14  11.70  11.95  12.28  11.70  3872084  4.637823e+09
# 3   7546  2022-11-11  11.13  11.43  11.66  11.01  2545071  2.878557e+09
# 4   7545  2022-11-10  10.79  10.87  10.90  10.69   552021  5.969166e+08
# 5   7544  2022-11-09  10.84  10.89  11.08  10.82   832107  9.111536e+08
# 6   7543  2022-11-08  10.89  10.85  10.92  10.78   583222  6.328358e+08
# 7   7542  2022-11-07  10.81  10.88  10.91  10.73   988082  1.070555e+09
# 8   7541  2022-11-04  10.40  10.82  10.85  10.39  1776112  1.903721e+09
# 9   7540  2022-11-03  10.54  10.44  10.57  10.38   983536  1.028904e+09
# 10  7539  2022-11-02  10.61  10.63  10.68  10.48  1302988  1.377816e+09
# 11  7538  2022-11-01  10.38  10.67  10.68  10.36  1381234  1.459758e+09
# ...

# %%
table_name = 'stock_a_codes'
sql_cmd = 'SELECT * FROM {};'.format(table_name)
db_df = pd.read_sql(sql=sql_cmd, con=engine)
db_df
# Out:
#         code   name
# 0     000001   平安银行
# 1     000002  万  科Ａ
# 2     000004   ST国华
# 3     000005   ST星源
# 4     000006   深振业Ａ
# ...      ...    ...
# 4987  873122    中纺标
# 4988  873169   七丰精工
# 4989  873223   荣亿精密
# 4990  873339    N恒太
# 4991  873527    夜光明
#
# [4992 rows x 2 columns]

# %%
code_list = db_df['code'].values.tolist()
code_list
# Out:
# ['000001',
#  '000002',
#  '000004',
#  '000005',
#  '000006',
#  '000007',
#  '000008',
#  '000009',
#  '000010',
#  '000011',
#  '000012',
#  '000014',
#  '000016',
#  '000017',
#  '000019',
#  '000020',
#  '000021',
#  '000023',
#  '000025',
#  '000026',
#  '000027',
#  '000028',
#  '000029',
#  '000030',
#  '000031',
#  '000032',
#  '000034',
#  '000035',
#  '000036',
#  '000037',
#  '000038',
#  '000039',
#  '000040',
#  '000042',
#  '000045',
#  '000046',
#  '000048',
#  '000049',
#  '000050',
#  '000055',
#  '000056',
#  '000058',
#  '000059',
#  '000060',
#  '000061',
#  '000062',
#  '000063',
#  '000065',
#  '000066',
#  '000068',
#  '000069',
#  '000070',
#  '000078',
#  '000088',
#  '000089',
#  '000090',
#  '000096',
#  '000099',
#  '000100',
#  '000150',
#  '000151',
#  '000153',
#  '000155',
#  '000156',
#  '000157',
#  '000158',
#  '000159',
#  '000166',
#  '000301',
#  '000333',
#  '000338',
#  '000400',
#  '000401',
#  '000402',
#  '000403',
#  '000404',
# ...

# %%
code_list = ['000001']

# %%
for code in code_list:
    table_name = f'stock_a_history_1d_{code}'
    sql_cmd = 'DROP TABLE {};'.format(table_name)
    try:
        engine.execute(sql_cmd)
        print(f'deleted {table_name}')
    except Exception as e:
        print(e)
# Out:
# deleted stock_a_history_1d_000001

# %%
import akshare as ak
import baostock as bs
import datetime

# %%
def wrap_query_a_summary_ak(date):
    """
    获取市场总览
    """
    df = ak.stock_szse_summary(date=date)
    return df

# %%
def get_trading_date_ak(date=None):
    """
    取得指定日期前市场最近交易日，这里的交易日特指有日线数据的交易日

    :param date: 日期字符串，默认为空，返回历史离当日最近的有日线的交易日（当日为交易日，若17:30前调用，也无日线数据）
    :return: 最近交易日日期字符串，格式'%Y-%m-%d'
    """

    # date为空时，将trade_date设置为当日
    if date is None:
        trading_date = datetime.date.today().strftime('%Y-%m-%d')

    # 否则将trade_date设置为指定date
    else:
        trading_date = date

    # 查询股票数据，query_all_stock与K线在17:30同时更新,向trading_date前寻找有K线数据的日期
    # while 0 == wrap_query_all_stock(trading_date).shape[0]:
    while 0 == wrap_query_a_summary_ak(trading_date.replace('-','', 2)).shape[0]:
        # trading_date向历史移动1天
        trading_date = (datetime.datetime.strptime(trading_date, '%Y-%m-%d') - datetime.timedelta(days=1)).strftime(
            '%Y-%m-%d')

    # 返回最近交易日日期
    return trading_date

# %%
get_trading_date_ak()
# Out:
# '2022-11-17'

# %%
def bs_func_decorator(func):
    """
    BaoStock方法装饰器

    调用BaoStock方法，如果失败，尝试重新连接BaoStock
    避免重复建立BaoStock连接

    :param args:
    :param func: BaoStock方法
    :return: 装饰器
    """

    # 装饰
    def wrap_func(*args, **kwargs):

        # 最多尝试次数
        retry_n = 5

        # 循环尝试查询复权数据，最多尝试retry_n次
        for i in range(retry_n):

            # 调用BaoStock方法
            rs = func(*args, **kwargs)

            # 如果查询成功，则返回查询结果
            if rs.error_code == '0':
                return rs.get_data()

            # 未查询成功，则尝试重新连接BaoStock
            else:
                print('重新连接BaoStock...')
                bs.login()

        # 无法连接，则程序退出
        print('无法连接BaoStock, 程序退出...')
        exit(0)

    return wrap_func

# %%
@bs_func_decorator
def wrap_query_all_stock(date):
    """
    装饰股票代码查询函数

    :param date: 需要查询的交易日期
    :return: 包含股票代码的DataFrame
    """

    return bs.query_all_stock(date)

# %%
def get_trading_date_bs(date=None):
    """
    取得指定日期前市场最近交易日，这里的交易日特指有日线数据的交易日

    :param date: 日期字符串，默认为空，返回历史离当日最近的有日线的交易日（当日为交易日，若17:30前调用，也无日线数据）
    :return: 最近交易日日期字符串，格式'%Y-%m-%d'
    """

    # date为空时，将trade_date设置为当日
    if date is None:
        trading_date = datetime.date.today().strftime('%Y-%m-%d')

    # 否则将trade_date设置为指定date
    else:
        trading_date = date

    # 查询股票数据，query_all_stock与K线在17:30同时更新,向trading_date前寻找有K线数据的日期
    if True:
        # use baostock
        while 0 == wrap_query_all_stock(trading_date).shape[0]:
            # trading_date向历史移动1天
            trading_date = (datetime.datetime.strptime(trading_date, '%Y-%m-%d') - datetime.timedelta(days=1)).strftime(
                '%Y-%m-%d')
    else:
        # use akshare
        while 0 == wrap_query_a_summary_ak(trading_date.replace('-','', 2)).shape[0]:
            # trading_date向历史移动1天
            trading_date = (datetime.datetime.strptime(trading_date, '%Y-%m-%d') - datetime.timedelta(days=1)).strftime(
                '%Y-%m-%d')

    # 返回最近交易日日期
    return trading_date

# %%
get_trading_date_bs()
# Out:
# '2022-11-16'

# %%
import baostock as bs
bs.logout()
bs.login()
rs_df = bs.query_dividend_data('sz.000001', '2022', yearType='report')
print(rs_df)
flag = False
if rs_df.shape[0] and rs_df['dividOperateDate'].iloc[-1] >= '2022':
    flag = True
else:
    flag = False
flag
# Out:
# logout success!
# login success!
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/afirez/studio/python/auto-trade/examples/py_postgres/py_postgres_sqlalchemy.ipynb Cell 9' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/Users/afirez/studio/python/auto-trade/examples/py_postgres/py_postgres_sqlalchemy.ipynb#ch0000008?line=4'>5</a> print(rs_df)
#       <a href='vscode-notebook-cell:/Users/afirez/studio/python/auto-trade/examples/py_postgres/py_postgres_sqlalchemy.ipynb#ch0000008?line=5'>6</a> flag = False
# ----> <a href='vscode-notebook-cell:/Users/afirez/studio/python/auto-trade/examples/py_postgres/py_postgres_sqlalchemy.ipynb#ch0000008?line=6'>7</a> if rs_df.shape[0] and rs_df['dividOperateDate'].iloc[-1] >= '2022':
# ...

# %%
# 1. 获取所有股票代码和名称
# df_all = ak.stock_zh_a_spot_em()
# print(df_all)
# df_all = df_all[["代码","名称"]]

# df_all2 = ak.stock_info_a_code_name()
# print(df_all2)

# 2. 遍历所有股票数据 获取历史行情数据：如
# symbol="002594"
# 
# em
# stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol=symbol, period="daily", start_date="20000301", end_date='20220729', adjust="")
# print(stock_zh_a_hist_df)
#
# sina
# stock_zh_a_daily_qfq_df = ak.stock_zh_a_daily(symbol=symbol, adjust="qfq")

# 3. 实时股票数据
# em 分页数据一次性加载
# 0.5s
stock_zh_a_spot_em_df = ak.stock_zh_a_spot_em()
print(stock_zh_a_spot_em_df)
# 
# sina 分页数据 慢
# stock_zh_a_spot_df = ak.stock_zh_a_spot()
# print(stock_zh_a_spot_df)
# Out:
#         序号      代码    名称    最新价    涨跌幅    涨跌额        成交量           成交额     振幅  \
# 0        1  688201  信安世纪  68.00  19.99  11.33    51326.0  3.292831e+08  18.00
# 1        2  301126  达嘉维康  20.36  19.98   3.39   192114.0  3.724411e+08  16.97
# 2        3  300753  爱朋医疗  17.80  14.25   2.22   132149.0  2.243449e+08  18.74
# 3        4  430685  新芝生物  16.15  13.57   1.93    27408.0  4.223338e+07  14.35
# 4        5  688618  三旺通信  88.70  13.28  10.40    10443.0  8.821882e+07  19.11
# ...    ...     ...   ...    ...    ...    ...        ...           ...    ...
# 5191  5192  605180  华生科技  17.85  -6.93  -1.33    84170.0  1.528418e+08   7.30
# 5192  5193  603777   来伊份  18.23  -7.08  -1.39   261646.0  4.906435e+08  14.37
# 5193  5194  000980  众泰汽车   6.54  -7.23  -0.51  2548697.0  1.709244e+09   6.38
# 5194  5195  301361   C众智  29.70  -7.79  -2.51   106799.0  3.188259e+08   7.20
# 5195  5196  600348  华阳股份  16.20  -8.27  -1.46  1147815.0  1.874675e+09   9.63
#
# ...

# %%
import akshare as ak
stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol='603029', period="daily", start_date="20221117", end_date='20221117', adjust="qfq")
stock_zh_a_hist_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
temp_df = stock_zh_a_spot_em_df[
    stock_zh_a_spot_em_df['成交量'] <= 0 
    # or stock_zh_a_spot_em_df['成交量'] == ''
]
temp_df
# Out:
# Empty DataFrame
# Columns: [序号, 代码, 名称, 最新价, 涨跌幅, 涨跌额, 成交量, 成交额, 振幅, 最高, 最低, 今开, 昨收, 量比, 换手率, 市盈率-动态, 市净率, 总市值, 流通市值, 涨速, 5分钟涨跌, 60日涨跌幅, 年初至今涨跌幅]
# Index: []
#
# [0 rows x 23 columns]

# %%
# 盘前数据
stock_zh_a_hist_pre_min_em_df = ak.stock_zh_a_hist_pre_min_em(symbol="002594")
# print(stock_zh_a_hist_pre_min_em_df)
stock_zh_a_hist_pre_min_em_df.head(45)
# Out:
#                      时间      开盘      收盘      最高      最低   成交量         成交额  \
# 0   2022-11-17 09:15:00  261.08  261.08  261.08  261.08     0         0.0
# 1   2022-11-17 09:16:00  261.05  260.00  261.08  260.00     0         0.0
# 2   2022-11-17 09:17:00  261.08  261.08  261.08  260.00     0         0.0
# 3   2022-11-17 09:18:00  261.08  261.08  261.08  261.08     0         0.0
# 4   2022-11-17 09:19:00  261.08  261.08  261.08  261.08     0         0.0
# 5   2022-11-17 09:20:00  261.08  261.08  261.08  261.08     0         0.0
# 6   2022-11-17 09:21:00  261.08  261.08  261.08  261.08     0         0.0
# 7   2022-11-17 09:22:00  261.08  261.06  261.08  261.06     0         0.0
# 8   2022-11-17 09:23:00  261.06  261.05  261.06  261.02     0         0.0
# 9   2022-11-17 09:24:00  261.01  260.30  261.01  260.30     0         0.0
# 10  2022-11-17 09:25:00  260.11  259.90  260.11  259.90     0         0.0
# 11  2022-11-17 09:26:00  259.91  259.91  259.91  259.91   855  22222305.0
# ...

# %%
# 东财分钟数据
stock_zh_a_hist_min_em_df = ak.stock_zh_a_hist_min_em(
    symbol="002594", 
    # start_date="2022-11-01 09:32:00",
    end_date="2022-11-17 14:59:00", 
    period='1', 
    adjust='qhq',
)
stock_zh_a_hist_min_em_df
# print(stock_zh_a_hist_min_em_df)
# Out:
#                        时间      开盘      收盘      最高      最低   成交量          成交额  \
# 0     2022-11-11 09:30:00    0.00  270.50  270.50  270.50  3900  105499869.0
# 1     2022-11-11 09:31:00    0.00  270.91  271.97  270.65  9437  255798780.0
# 2     2022-11-11 09:32:00    0.00  270.10  271.00  270.03  6284  170086294.0
# 3     2022-11-11 09:33:00    0.00  271.36  271.42  270.02  5623  152349372.0
# 4     2022-11-11 09:34:00    0.00  271.50  272.97  271.35  6254  170185820.0
# ...                   ...     ...     ...     ...     ...   ...          ...
# 1199  2022-11-17 14:55:00  256.69  256.68  256.70  256.60   580   14887284.0
# 1200  2022-11-17 14:56:00  256.68  256.83  256.90  256.68   668   17152402.0
# 1201  2022-11-17 14:57:00  256.90  256.98  256.99  256.90   581   14931142.0
# 1202  2022-11-17 14:58:00  257.00  257.00  257.00  257.00    18     462571.0
# 1203  2022-11-17 14:59:00  257.00  257.00  257.00  257.00     0          0.0
#
#           最新价
# 0     270.500
# ...

# %%
try:
    # 利用新浪财经接口获取20000条分钟级股票数据
    df= ak.stock_zh_a_minute(symbol='sz002594', period='1', adjust='qfq')
except Exception as e:
    print(e)
df
# Out:
#                        day        open        high         low       close  \
# 0      2022-05-16 14:47:00  267.549825  267.589811  267.479848  267.589811
# 1      2022-05-16 14:48:00  267.589811  267.629798  267.569818  267.609805
# 2      2022-05-16 14:49:00  267.609805  267.619801  267.579815  267.609805
# 3      2022-05-16 14:50:00  267.619801  267.919700  267.589811  267.779747
# 4      2022-05-16 14:51:00  267.639794  267.799741  267.609805  267.789744
# ...                    ...         ...         ...         ...         ...
# 29995  2022-11-17 14:54:00         NaN         NaN         NaN         NaN
# 29996  2022-11-17 14:55:00         NaN         NaN         NaN         NaN
# 29997  2022-11-17 14:56:00         NaN         NaN         NaN         NaN
# 29998  2022-11-17 14:57:00         NaN         NaN         NaN         NaN
# 29999  2022-11-17 15:00:00         NaN         NaN         NaN         NaN
#
#        volume
# 0       21700
# 1       37600
# 2       32300
# ...

# %%
path = f"/Users/afirez/studio/python/auto-trade/modules/Ashare/"
import sys
sys.path.append(path)
from Ashare import get_price

# %%
df=get_price('sz002594',frequency='1m',count=20)
df
# Out:
#                        open   close    high     low  volume
#
# 2022-11-17 14:41:00  255.04  255.16  255.16  255.04   302.0
# 2022-11-17 14:42:00  255.16  255.34  255.34  255.16   238.0
# 2022-11-17 14:43:00  255.48  255.44  255.50  255.40   639.0
# 2022-11-17 14:44:00  255.34  255.37  255.46  255.34   238.0
# 2022-11-17 14:45:00  255.40  255.42  255.42  255.36   322.0
# 2022-11-17 14:46:00  255.42  255.55  255.60  255.42   307.0
# 2022-11-17 14:47:00  255.62  255.90  255.90  255.59   726.0
# 2022-11-17 14:48:00  256.00  256.19  256.21  256.00   411.0
# 2022-11-17 14:49:00  256.28  256.40  256.40  256.27   730.0
# 2022-11-17 14:50:00  256.48  256.56  256.78  256.46   517.0
# 2022-11-17 14:51:00  256.50  256.33  256.50  256.33   518.0
# 2022-11-17 14:52:00  256.36  256.25  256.36  256.25   390.0
# 2022-11-17 14:53:00  256.26  256.36  256.36  256.25   301.0
# 2022-11-17 14:54:00  256.39  256.68  256.68  256.39   498.0
# 2022-11-17 14:55:00  256.69  256.68  256.70  256.60   580.0
# ...

# %%
df=get_price('sz300750',frequency='1m',count=20)
df
# Out:
#                        open   close    high     low  volume
#
# 2022-11-17 14:41:00  372.31  372.40  372.47  372.30   343.0
# 2022-11-17 14:42:00  372.41  372.40  372.41  372.35   421.0
# 2022-11-17 14:43:00  372.46  372.37  372.50  372.37   502.0
# 2022-11-17 14:44:00  372.33  372.22  372.37  372.11   509.0
# 2022-11-17 14:45:00  372.17  372.37  372.37  372.08   528.0
# 2022-11-17 14:46:00  372.21  372.70  372.70  372.21   489.0
# 2022-11-17 14:47:00  372.70  373.25  373.25  372.70   487.0
# 2022-11-17 14:48:00  373.15  373.52  373.52  373.15   601.0
# 2022-11-17 14:49:00  373.47  373.78  373.78  373.47   361.0
# 2022-11-17 14:50:00  373.75  373.99  373.99  373.75   423.0
# 2022-11-17 14:51:00  373.99  374.18  374.18  373.99   464.0
# 2022-11-17 14:52:00  374.18  374.43  374.47  374.18   452.0
# 2022-11-17 14:53:00  374.35  375.01  375.18  374.35  1342.0
# 2022-11-17 14:54:00  375.06  374.40  375.06  374.39   890.0
# 2022-11-17 14:55:00  374.36  374.90  374.90  374.36   488.0
# ...
