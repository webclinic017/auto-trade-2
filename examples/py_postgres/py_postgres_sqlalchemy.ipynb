# %%
import sqlalchemy 

db_pg = {
    # "host": "192.168.31.110",
    # "host": "192.168.0.135",
    "host": "127.0.0.1",
    "port": 5433, # alpha-pg 
    "user": "postgres",
    "password": "postgres",
    "db": "k_house",
}
user = db_pg["user"]
password = db_pg["password"]
host = db_pg["host"]
port = db_pg["port"]
dbname = db_pg["db"]

url=f'postgresql://{user}:{password}@{host}:{port}/{dbname}'

# %%
import sqlalchemy
from sqlalchemy_utils import database_exists, create_database
engine = sqlalchemy.create_engine(
    url=f'postgresql://{user}:{password}@{host}:{port}/{dbname}',)
if not database_exists(engine.url):
    print(f'not exit db {engine.url}')
    create_database(engine.url)
print(f'exit db {database_exists(engine.url)}: {engine.url}')
# Out:
# exit db True: postgresql://postgres:postgres@127.0.0.1:5433/k_house

# %%
engine = sqlalchemy.create_engine(url= url)
insp = sqlalchemy.inspect(engine)

# %%
insp.get_table_names()
# Out:
# ['stock_sz_a_spot_em',
#  'stock_sector_spot_sina',
#  'stock_institute_hold_sina',
#  'stock_zh_a_daily_test',
#  'stock_zh_a_hist_daily_test',
#  'stock_zh_a_hist_163_daily_test',
#  'stock_zh_a_hist_minute_sina_test',
#  'stock_zh_a_hist_minute_em_test',
#  'stock_zh_a_hist_pre_minute_em_test',
#  'stock_zh_a_tick_tx_test',
#  'stock_zh_a_tick_tx_js_test',
#  'stock_zh_a_tick_163_test',
#  'stock_info_a_code_name_test',
#  'stock_zh_index_spot_test',
#  'stock_zh_a_spot_test',
#  'stock_zh_a_spot_em_test',
#  'stock_sh_a_spot_em',
#  'stock_a_history_1d_000001',
#  'stock_a_codes',
#  'stock_info_a_code_name']

# %%
import pandas as pd

# %%
table_name = 'stock_a_history_1d_000001'
query_days = 20 
sql_cmd = 'SELECT * FROM {} LIMIT {};'.format(table_name, query_days)
db_df = pd.read_sql(sql=sql_cmd, con=engine)
db_df
# Out:
#     id        date  open  close  high   low  volume    amount  amplitude  \
# 0    0  1991-04-03 -0.97  -0.97 -0.97 -0.97       1    5000.0        0.0
# 1    1  1991-04-04 -0.97  -0.97 -0.97 -0.97       3   15000.0        0.0
# 2    2  1991-04-05 -0.97  -0.97 -0.97 -0.97       2   10000.0        0.0
# 3    3  1991-04-06 -0.97  -0.97 -0.97 -0.97       7   34000.0        0.0
# 4    4  1991-04-08 -0.97  -0.97 -0.97 -0.97       2   10000.0        0.0
# 5    5  1991-04-09 -0.97  -0.97 -0.97 -0.97       4   19000.0        0.0
# 6    6  1991-04-10 -0.97  -0.97 -0.97 -0.97      15   71000.0        0.0
# 7    7  1991-04-12 -0.98  -0.98 -0.98 -0.98       8   38000.0        0.0
# 8    8  1991-04-13 -0.98  -0.98 -0.98 -0.98       5   23000.0        0.0
# 9    9  1991-04-16 -0.98  -0.98 -0.98 -0.98       2    9000.0        0.0
# 10  10  1991-04-17 -0.98  -0.98 -0.98 -0.98       1    4615.0        0.0
# 11  11  1991-04-18 -0.98  -0.98 -0.98 -0.98       4   18000.0        0.0
# 12  12  1991-04-19 -0.99  -0.99 -0.99 -0.99       2    9000.0        0.0
# 13  13  1991-04-20 -0.99  -0.99 -0.99 -0.99       5   23000.0        0.0
# 14  14  1991-04-23 -0.99  -0.99 -0.99 -0.99      28  126000.0        0.0
# 15  15  1991-04-24 -0.99  -0.99 -0.99 -0.99      16   72000.0        0.0
# 16  16  1991-04-25 -0.99  -0.99 -0.99 -0.99      15   67000.0        0.0
# 17  17  1991-04-26 -0.99  -0.99 -0.99 -0.99       8   35000.0        0.0
# 18  18  1991-04-29 -1.00  -1.00 -1.00 -1.00       4   17000.0        0.0
# 19  19  1991-04-30 -1.00  -1.00 -1.00 -1.00       2    9000.0        0.0
#
#     pctChg   chg  turn     zt     ss  candidate
# 0     4.90  0.05  0.00  False  False      False
# 1     0.00  0.00  0.00   True  False      False
# 2     0.00  0.00  0.00   True  False      False
# 3     0.00  0.00  0.00   True  False      False
# 4     0.00  0.00  0.00   True  False      False
# 5     0.00  0.00  0.00   True  False      False
# 6     0.00  0.00  0.00   True  False      False
# 7    -1.03 -0.01  0.00   True  False      False
# 8     0.00  0.00  0.00   True  False      False
# 9     0.00  0.00  0.00   True  False      False
# 10    0.00  0.00  0.00   True  False      False
# 11    0.00  0.00  0.00   True  False      False
# 12   -1.02 -0.01  0.00   True  False      False
# 13    0.00  0.00  0.00   True  False      False
# 14    0.00  0.00  0.01   True  False      False
# 15    0.00  0.00  0.00   True  False      False
# 16    0.00  0.00  0.00   True  False      False
# 17    0.00  0.00  0.00   True  False      False
# 18   -1.01 -0.01  0.00   True  False      False
# 19    0.00  0.00  0.00   True  False      False

# %%
table_name = 'stock_a_history_1d_000001'
query_days = 20 
sql_cmd = 'SELECT * FROM {} ORDER BY date DESC LIMIT {};'.format(table_name, query_days)
db_df = pd.read_sql(sql=sql_cmd, con=engine)
db_df
# last_id = db_df['id'].iloc[-1]
# last_id
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File /usr/local/anaconda3/envs/py38/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File /usr/local/anaconda3/envs/py38/lib/python3.8/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# UndefinedTable: relation "stock_a_history_1d_000001" does not exist
# LINE 1: SELECT * FROM stock_a_history_1d_000001 ORDER BY date DESC L...
#                       ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# /Users/afirez/studio/python/auto-trade/examples/py_postgres/py_postgres_sqlalchemy.ipynb Cell 7' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/afirez/studio/python/auto-trade/examples/py_postgres/py_postgres_sqlalchemy.ipynb#ch0000006?line=1'>2</a> query_days = 20
#       <a href='vscode-notebook-cell:/Users/afirez/studio/python/auto-trade/examples/py_postgres/py_postgres_sqlalchemy.ipynb#ch0000006?line=2'>3</a> sql_cmd = 'SELECT * FROM {} ORDER BY date DESC LIMIT {};'.format(table_name, query_days)
# ----> <a href='vscode-notebook-cell:/Users/afirez/studio/python/auto-trade/examples/py_postgres/py_postgres_sqlalchemy.ipynb#ch0000006?line=3'>4</a> db_df = pd.read_sql(sql=sql_cmd, con=engine)
#       <a href='vscode-notebook-cell:/Users/afirez/studio/python/auto-trade/examples/py_postgres/py_postgres_sqlalchemy.ipynb#ch0000006?line=4'>5</a> db_df
#
# File /usr/local/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/io/sql.py:628, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     619     return pandas_sql.read_table(
#     620         sql,
#     621         index_col=index_col,
#    (...)
#     625         chunksize=chunksize,
#     626     )
#     627 else:
# --> 628     return pandas_sql.read_query(
#     629         sql,
#     630         index_col=index_col,
#     631         params=params,
#     632         coerce_float=coerce_float,
#     633         parse_dates=parse_dates,
#     634         chunksize=chunksize,
#     635     )
#
# File /usr/local/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/io/sql.py:1579, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1531 """
#    1532 Read SQL query into a DataFrame.
#    1533
#    (...)
#    1575
#    1576 """
#    1577 args = _convert_params(sql, params)
# -> 1579 result = self.execute(*args)
#    1580 columns = result.keys()
#    1582 if chunksize is not None:
#
# File /usr/local/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/io/sql.py:1424, in SQLDatabase.execute(self, *args, **kwargs)
#    1422 def execute(self, *args, **kwargs):
#    1423     """Simple passthrough to SQLAlchemy connectable"""
# -> 1424     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File /usr/local/anaconda3/envs/py38/lib/python3.8/site-packages/sqlalchemy/util/deprecations.py:402, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     400 if not skip_warning:
#     401     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 402 return fn(*args, **kwargs)
#
# File /usr/local/anaconda3/envs/py38/lib/python3.8/site-packages/sqlalchemy/engine/base.py:3176, in Engine.execute(self, statement, *multiparams, **params)
#    3158 """Executes the given construct and returns a
#    3159 :class:`_engine.CursorResult`.
#    3160
#    (...)
#    3173
#    3174 """
#    3175 connection = self.connect(close_with_result=True)
# -> 3176 return connection.execute(statement, *multiparams, **params)
#
# File /usr/local/anaconda3/envs/py38/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1291, in Connection.execute(self, statement, *multiparams, **params)
#    1282 if isinstance(statement, util.string_types):
#    1283     util.warn_deprecated_20(
#    1284         "Passing a string to Connection.execute() is "
#    1285         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1288         "driver-level SQL string."
#    1289     )
# -> 1291     return self._exec_driver_sql(
#    1292         statement,
#    1293         multiparams,
#    1294         params,
#    1295         _EMPTY_EXECUTION_OPTS,
#    1296         future=False,
#    1297     )
#    1299 try:
#    1300     meth = statement._execute_on_connection
#
# File /usr/local/anaconda3/envs/py38/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1595, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1585         (
#    1586             statement,
#    1587             distilled_params,
#    (...)
#    1591             statement, distilled_parameters, execution_options
#    1592         )
#    1594 dialect = self.dialect
# -> 1595 ret = self._execute_context(
#    1596     dialect,
#    1597     dialect.execution_ctx_cls._init_statement,
#    1598     statement,
#    1599     distilled_parameters,
#    1600     execution_options,
#    1601     statement,
#    1602     distilled_parameters,
#    1603 )
#    1605 if not future:
#    1606     if self._has_events or self.engine._has_events:
#
# File /usr/local/anaconda3/envs/py38/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File /usr/local/anaconda3/envs/py38/lib/python3.8/site-packages/sqlalchemy/engine/base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /usr/local/anaconda3/envs/py38/lib/python3.8/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File /usr/local/anaconda3/envs/py38/lib/python3.8/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File /usr/local/anaconda3/envs/py38/lib/python3.8/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedTable) relation "stock_a_history_1d_000001" does not exist
# LINE 1: SELECT * FROM stock_a_history_1d_000001 ORDER BY date DESC L...
#                       ^
#
# [SQL: SELECT * FROM stock_a_history_1d_000001 ORDER BY date DESC LIMIT 20;]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
table_name = 'stock_a_codes'
sql_cmd = 'SELECT * FROM {};'.format(table_name)
db_df = pd.read_sql(sql=sql_cmd, con=engine)
db_df
# Out:
#         code   name
# 0     000001   平安银行
# 1     000002  万  科Ａ
# 2     000004   ST国华
# 3     000005   ST星源
# 4     000006   深振业Ａ
# ...      ...    ...
# 4987  873122    中纺标
# 4988  873169   七丰精工
# 4989  873223   荣亿精密
# 4990  873339    N恒太
# 4991  873527    夜光明
#
# [4992 rows x 2 columns]

# %%
code_list = db_df['code'].values.tolist()
code_list
# Out:
# ['000001',
#  '000002',
#  '000004',
#  '000005',
#  '000006',
#  '000007',
#  '000008',
#  '000009',
#  '000010',
#  '000011',
#  '000012',
#  '000014',
#  '000016',
#  '000017',
#  '000019',
#  '000020',
#  '000021',
#  '000023',
#  '000025',
#  '000026',
#  '000027',
#  '000028',
#  '000029',
#  '000030',
#  '000031',
#  '000032',
#  '000034',
#  '000035',
#  '000036',
#  '000037',
#  '000038',
#  '000039',
#  '000040',
#  '000042',
#  '000045',
#  '000046',
#  '000048',
#  '000049',
#  '000050',
#  '000055',
#  '000056',
#  '002401',
#  '002402',
#  '002403',
#  '002404',
#  '002405',
#  '002406',
#  '002407',
#  '002408',
#  '002409',
#  '002410',
#  '002411',
#  '002412',
#  '002413',
#  '002414',
#  '002415',
#  '002416',
#  '002417',
#  '002418',
#  '002419',
#  '002420',
#  '002421',
#  '002422',
#  '002423',
#  '002424',
#  '002425',
#  '002426',
#  '002427',
#  '002428',
#  '002429',
#  '002430',
#  '002431',
#  '002432',
#  '002433',
#  '002434',
#  '002435',
#  '002436',
#  '002437',
#  '002438',
#  '002439',
#  '002440',
#  '002441',
#  '002442',
#  '002443',
#  '002444',
#  '002445',
#  '002446',
#  '002448',
#  '002449',
#  '002451',
#  '002452',
#  '002453',
#  '002454',
#  '002455',
#  '002456',
#  '002457',
#  '002458',
#  '002459',
#  '002460',
#  '002461',
#  '002462',
#  '002463',
#  '002465',
#  '002466',
#  '002467',
#  '002468',
#  '002469',
#  '002470',
#  '002471',
#  '002472',
#  '002474',
#  '002475',
#  '002476',
#  '002478',
#  '002479',
#  '002480',
#  '002481',
#  '002482',
#  '002483',
#  '002484',
#  '002485',
#  '002486',
#  '002487',
#  '002488',
#  '002489',
#  '002490',
#  '002491',
#  '002492',
#  '002493',
#  '002494',
#  '002495',
#  '002496',
#  '002497',
#  '002498',
#  '002499',
#  '002500',
#  '002501',
#  '002502',
#  '002503',
#  '002504',
#  '002505',
#  '002506',
#  '002507',
#  '002508',
#  ...]

# %%
code_list = ['000001']

# %%
for code in code_list:
    table_name = f'stock_a_history_1d_{code}'
    sql_cmd = 'DROP TABLE {};'.format(table_name)
    try:
        engine.execute(sql_cmd)
        print(f'deleted {table_name}')
    except Exception as e:
        print(e)
# Out:
# deleted stock_a_history_1d_000001

# %%
import akshare as ak
import baostock as bs
import datetime

# %%
def wrap_query_a_summary_ak(date):
    """
    获取市场总览
    """
    df = ak.stock_szse_summary(date=date)
    return df

# %%
def get_trading_date_ak(date=None):
    """
    取得指定日期前市场最近交易日，这里的交易日特指有日线数据的交易日

    :param date: 日期字符串，默认为空，返回历史离当日最近的有日线的交易日（当日为交易日，若17:30前调用，也无日线数据）
    :return: 最近交易日日期字符串，格式'%Y-%m-%d'
    """

    # date为空时，将trade_date设置为当日
    if date is None:
        trading_date = datetime.date.today().strftime('%Y-%m-%d')

    # 否则将trade_date设置为指定date
    else:
        trading_date = date

    # 查询股票数据，query_all_stock与K线在17:30同时更新,向trading_date前寻找有K线数据的日期
    # while 0 == wrap_query_all_stock(trading_date).shape[0]:
    while 0 == wrap_query_a_summary_ak(trading_date.replace('-','', 2)).shape[0]:
        # trading_date向历史移动1天
        trading_date = (datetime.datetime.strptime(trading_date, '%Y-%m-%d') - datetime.timedelta(days=1)).strftime(
            '%Y-%m-%d')

    # 返回最近交易日日期
    return trading_date

# %%
get_trading_date_ak()
# Out:
# '2022-11-16'

# %%
def bs_func_decorator(func):
    """
    BaoStock方法装饰器

    调用BaoStock方法，如果失败，尝试重新连接BaoStock
    避免重复建立BaoStock连接

    :param args:
    :param func: BaoStock方法
    :return: 装饰器
    """

    # 装饰
    def wrap_func(*args, **kwargs):

        # 最多尝试次数
        retry_n = 5

        # 循环尝试查询复权数据，最多尝试retry_n次
        for i in range(retry_n):

            # 调用BaoStock方法
            rs = func(*args, **kwargs)

            # 如果查询成功，则返回查询结果
            if rs.error_code == '0':
                return rs.get_data()

            # 未查询成功，则尝试重新连接BaoStock
            else:
                print('重新连接BaoStock...')
                bs.login()

        # 无法连接，则程序退出
        print('无法连接BaoStock, 程序退出...')
        exit(0)

    return wrap_func

# %%
@bs_func_decorator
def wrap_query_all_stock(date):
    """
    装饰股票代码查询函数

    :param date: 需要查询的交易日期
    :return: 包含股票代码的DataFrame
    """

    return bs.query_all_stock(date)

# %%
def get_trading_date_bs(date=None):
    """
    取得指定日期前市场最近交易日，这里的交易日特指有日线数据的交易日

    :param date: 日期字符串，默认为空，返回历史离当日最近的有日线的交易日（当日为交易日，若17:30前调用，也无日线数据）
    :return: 最近交易日日期字符串，格式'%Y-%m-%d'
    """

    # date为空时，将trade_date设置为当日
    if date is None:
        trading_date = datetime.date.today().strftime('%Y-%m-%d')

    # 否则将trade_date设置为指定date
    else:
        trading_date = date

    # 查询股票数据，query_all_stock与K线在17:30同时更新,向trading_date前寻找有K线数据的日期
    if True:
        # use baostock
        while 0 == wrap_query_all_stock(trading_date).shape[0]:
            # trading_date向历史移动1天
            trading_date = (datetime.datetime.strptime(trading_date, '%Y-%m-%d') - datetime.timedelta(days=1)).strftime(
                '%Y-%m-%d')
    else:
        # use akshare
        while 0 == wrap_query_a_summary_ak(trading_date.replace('-','', 2)).shape[0]:
            # trading_date向历史移动1天
            trading_date = (datetime.datetime.strptime(trading_date, '%Y-%m-%d') - datetime.timedelta(days=1)).strftime(
                '%Y-%m-%d')

    # 返回最近交易日日期
    return trading_date

# %%
get_trading_date_bs()
# Out:
# '2022-11-16'

# %%
# 1. 获取所有股票代码和名称
# df_all = ak.stock_zh_a_spot_em()
# print(df_all)
# df_all = df_all[["代码","名称"]]

# df_all2 = ak.stock_info_a_code_name()
# print(df_all2)

# 2. 遍历所有股票数据 获取历史行情数据：如
# symbol="002594"
# 
# em
# stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol=symbol, period="daily", start_date="20000301", end_date='20220729', adjust="")
# print(stock_zh_a_hist_df)
#
# sina
# stock_zh_a_daily_qfq_df = ak.stock_zh_a_daily(symbol=symbol, adjust="qfq")

# 3. 实时股票数据
# em 分页数据一次性加载
# 0.5s
stock_zh_a_spot_em_df = ak.stock_zh_a_spot_em()
print(stock_zh_a_spot_em_df)
# 
# sina 分页数据 慢
# stock_zh_a_spot_df = ak.stock_zh_a_spot()
# print(stock_zh_a_spot_df)
# Out:
#         序号      代码    名称    最新价    涨跌幅    涨跌额        成交量           成交额     振幅  \
# 0        1  301126  达嘉维康  20.36  19.98   3.39   191072.0  3.703201e+08  16.97
# 1        2  688201  信安世纪  66.20  16.82   9.53    45250.0  2.884053e+08  17.93
# 2        3  300659  中孚信息  30.94  13.88   3.77   119472.0  3.438874e+08  20.68
# 3        4  688618  三旺通信  88.45  12.96  10.15     9696.0  8.161283e+07  19.11
# 4        5  301159  三维天地  31.25  12.37   3.44    54562.0  1.666249e+08  17.58
# ...    ...     ...   ...    ...    ...    ...        ...           ...    ...
# 5191  5192  603348  文灿股份  63.86  -7.31  -5.04    53307.0  3.461803e+08   7.81
# 5192  5193  301361   C众智  29.75  -7.64  -2.46    94357.0  2.817107e+08   7.20
# 5193  5194  600348  华阳股份  16.12  -8.72  -1.54  1100016.0  1.797444e+09   9.63
# 5194  5195  688021  奥福环保  26.36  -8.88  -2.57    29838.0  8.092855e+07   9.57
# 5195  5196  603777   来伊份  17.75  -9.53  -1.87   218822.0  4.140504e+08  14.37
#
#          最高  ...    量比    换手率   市盈率-动态   市净率           总市值          流通市值  \
# 0     20.36  ...  2.33  37.01    59.64  2.44  4.204456e+09  1.051114e+09
# 1     67.96  ...  2.15   7.36   125.75  8.80  9.124285e+09  4.067853e+09
# 2     32.32  ...  1.18   7.78   -13.74  5.38  7.008936e+09  4.752254e+09
# 3     91.96  ...  1.58   5.86    54.32  5.91  4.469157e+09  1.463323e+09
# 4     32.55  ...  2.89  28.20   -27.12  2.94  2.417188e+09  6.046875e+08
# ...     ...  ...   ...    ...      ...   ...           ...           ...
# 5191  68.38  ...  1.53   2.04    48.80  5.62  1.682865e+10  1.667807e+10
# 5192  30.98  ...  0.59  34.21    61.14  3.48  3.460996e+09  8.206543e+08
# 5193  17.59  ...  3.40   4.57     5.86  1.63  3.876860e+10  3.876860e+10
# 5194  28.87  ...  3.14   3.86 -1586.03  2.21  2.037195e+09  2.037195e+09
# 5195  20.48  ...  1.51   6.50    63.37  3.36  5.973938e+09  5.973938e+09
#
#         涨速  5分钟涨跌  60日涨跌幅  年初至今涨跌幅
# 0     0.00   0.00    5.93   -10.15
# 1    -0.21  -0.47   81.67    57.66
# 2     0.85  -1.31   51.00   -31.62
# 3     0.44   0.84   53.43   100.89
# 4     0.39   0.00    2.06     3.48
# ...    ...    ...     ...      ...
# 5191  0.02  -0.11  -26.17     9.61
# 5192 -1.03   1.02   12.52    12.52
# 5193 -0.12   0.06  -26.96    42.03
# 5194 -0.19   0.08   -7.08   -49.97
# 5195  0.51  -0.95   35.60    18.49
#
# [5196 rows x 23 columns]

# %%
temp_df = stock_zh_a_spot_em_df[
    stock_zh_a_spot_em_df['成交量'] <= 0 
    # or stock_zh_a_spot_em_df['成交量'] == ''
]
temp_df
# Out:
# Empty DataFrame
# Columns: [序号, 代码, 名称, 最新价, 涨跌幅, 涨跌额, 成交量, 成交额, 振幅, 最高, 最低, 今开, 昨收, 量比, 换手率, 市盈率-动态, 市净率, 总市值, 流通市值, 涨速, 5分钟涨跌, 60日涨跌幅, 年初至今涨跌幅]
# Index: []
#
# [0 rows x 23 columns]
